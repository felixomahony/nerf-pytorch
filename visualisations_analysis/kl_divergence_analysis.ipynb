# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/nerf-pytorch-master
# Out:
# /content/drive/MyDrive/nerf-pytorch-master

# %%
import get_kl_divergence

kl_0 = get_kl_divergence.get_kl_divergence("pickle_files/overlap_analysis/0.pkl")
kl_1 = get_kl_divergence.get_kl_divergence("pickle_files/overlap_analysis/1.pkl")
kl_2 = get_kl_divergence.get_kl_divergence("pickle_files/overlap_analysis/2.pkl")
kl_3 = get_kl_divergence.get_kl_divergence("pickle_files/overlap_analysis/3.pkl")

print("kl_0:", kl_0)
print("kl_1:", kl_1)
print("kl_2:", kl_2)
print("kl_3:", kl_3)
# Out:
# -4.57912727336703 -2 166.7246641286206 42.44138997678626
# -5.554345079304916 -2 149.55041238501985 29.658169379464915
# -3.0344500214963475 -2 99.69343668590194 43.84880454286821
# -2.666262054954519 -2 144.74445291727775 28.47479507191285
# kl_0: 101.29346341601992
# kl_1: 85.82711834258993
# kl_2: 69.2538956036369
# kl_3: 84.27649296711803
